# %% [markdown]
# ![alt text]({AC17652E-5BAE-42CB-9D35-E14E6A63C04B}.png)

# %% [markdown]
# ![alt text]({AAB501C6-8A5F-4D61-9EC7-397B5A560604}.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

pontos = []
i = 0
while i < 1:
    f = np.sin(2 * np.pi * i)
    pontos.append(f)
    i += 0.01

plt.plot(pontos, marker='o', linestyle='-', color='b')
plt.title('2*pi*x')
plt.xlabel('Índice')
# Out:
# Text(0.5, 0, 'Índice')

# %%
import numpy as np
import matplotlib.pyplot as plt

i = 0
pontos = []
while i < 1:
    f = np.cos(2 * np.pi * i) * -(2*np.pi)**(-1)
    pontos.append(f)
    i += 0.01

plt.plot(pontos, marker='o', linestyle='-', color='r')
plt.title('cos(2 * pi * i) * -(2*pi)**(-1)')
plt.xlabel('Índice')
# Out:
# Text(0.5, 0, 'Índice')

# %% [markdown]
# Se imaginarmos o gráfico dividido pelo eixo x em zero, a área acima do eixo é igual à área abaixo do eixo. O resultado analítico (zero) diz que as áreas se anulam. Do ponto de vista físico faz sentido, pois se imaginarmos que este é um gráfico de força pelo tempo, a força negativa representaria um vetor no sentido oposto, que anularia a força positiva em um impulso.

# %% [markdown]
# ![alt text]({C948F4CC-B7FC-4597-9D88-5432D1B02B45}.png)

# %%
def f(x):
    return np.sin(2 * np.pi * x)

N = 10
a = 0.0
b = 1.0
h = (b-a)/N


pontos = []
s = 0.5*f(a) + 0.5*f(b)
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(h*s)

plt.plot(pontos, marker='o', linestyle='-', color='r')
plt.title('2*pi*cos(2*pi*x)')
plt.xlabel('Índice')
# Out:
# -4.4408920985006264e-17
# Text(0.5, 0, 'Índice')

# %% [markdown]
# O valor retornado pela função foi -4.4408920985006264e-17, e o resultado analítico é zero. Portanto, o erro absoluto é o próprio valor retornado pela função pois, por mínimo que seja, ocorre por limitações da linguagem de programação.

# %% [markdown]
# ![alt text]({DBA8EE8E-A250-459B-8A29-7F4991617B32}.png)

# %%
import numpy as np

def regra_simpson(f, a, b, n):
    """
    Calcula a integral definida de uma função 'f' de 'a' até 'b'
    usando a Regra de 1/3 de Simpson com 'n' intervalos.

    Parâmetros:
    f (function): A função a ser integrada. Deve aceitar um número (float/int) e retornar um número.
    a (float): O limite inferior de integração.
    b (float): O limite superior de integração.
    n (int): O número de intervalos para a aproximação. DEVE SER UM NÚMERO PAR.
    
    Retorna:
    float: O valor aproximado da integral.
    """
    
    # Calcula a largura de cada intervalo (h)
    h = (b - a) / n

    # Soma dos termos nas extremidades
    soma = f(a) + f(b)

    # Soma dos termos com coeficiente 4 (índices ímpares)
    for i in range(1, n, 2):
        x = a + i * h
        soma += 4 * f(x)

    # Soma dos termos com coeficiente 2 (índices pares)
    for i in range(2, n, 2):
        x = a + i * h
        soma += 2 * f(x)

    # Aplica a fórmula final
    integral = (h / 3) * soma
    return integral

# --- Exemplo de Uso ---

# 1. Defina a função que você quer integrar.
#    Vamos usar f(x) = x^2, cuja integral de 0 a 3 é exatamente 9.
def minha_funcao(x):
    return np.sin(2 * np.pi * x)

# 2. Defina os limites de integração e o número de intervalos.
limite_inferior = 0
limite_superior = 1
num_intervalos = 10 # Um número par para boa precisão

# 3. Chame a função e imprima o resultado.
resultado = regra_simpson(minha_funcao, limite_inferior, limite_superior, num_intervalos)
print(f"Exemplo 1: Integral de x^2 de {limite_inferior} a {limite_superior}")
print(f"Resultado aproximado: {resultado}")
print("Resultado exato: 0.0\n")
# Out:
# Exemplo 1: Integral de x^2 de 0 a 1
# Resultado aproximado: -2.960594732333751e-17
# Resultado exato: 0.0

# %% [markdown]
# ![alt text]({D743DDA8-2724-4FEB-BA53-60FABF3CE205}.png)

# %% [markdown]
# # Trapezio

# %% [markdown]
# 100:

# %%
def f(x):
    return np.sin(2 * np.pi * x)

N = 100
a = 0.0
b = 1.0
h = (b-a)/N


pontos = []
s = 0.5*f(a) + 0.5*f(b)
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(h*s)

plt.plot(pontos, marker='o', linestyle='-', color='r')
plt.title('2*pi*cos(2*pi*x)')
plt.xlabel('Índice')
# Out:
# 7.674416657721395e-17
# Text(0.5, 0, 'Índice')

# %% [markdown]
# 1000:

# %%
def f(x):
    return np.sin(2 * np.pi * x)

N = 1000
a = 0.0
b = 1.0
h = (b-a)/N


pontos = []
s = 0.5*f(a) + 0.5*f(b)
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(h*s)

plt.plot(pontos, marker='o', linestyle='-', color='r')
plt.title('2*pi*cos(2*pi*x)')
plt.xlabel('Índice')
# Out:
# -2.326524389806295e-17
# Text(0.5, 0, 'Índice')

# %% [markdown]
# # simpson

# %% [markdown]
# 100

# %%
import numpy as np

def regra_simpson(f, a, b, n):
    pontos = []
    # Calcula a largura de cada intervalo (h)
    h = (b - a) / n

    # Soma dos termos nas extremidades
    soma = f(a) + f(b)
    pontos.append((h / 3) * soma)
    # Soma dos termos com coeficiente 4 (índices ímpares)
    for i in range(1, n, 2):
        x = a + i * h
        soma += 4 * f(x)
        pontos.append((h / 3) * soma)

    # Soma dos termos com coeficiente 2 (índices pares)
    for i in range(2, n, 2):
        x = a + i * h
        soma += 2 * f(x)
        pontos.append((h / 3) * soma)
    # Aplica a fórmula final
    integral = (h / 3) * soma

    plt.plot(pontos, marker='o', linestyle='-', color='r')
    plt.title('2*pi*cos(2*pi*x)')
    plt.xlabel('Índice')


    return integral

# --- Exemplo de Uso ---

def minha_funcao(x):
    return np.sin(2 * np.pi * x)

# 2. Defina os limites de integração e o número de intervalos.
limite_inferior = 0
limite_superior = 1
num_intervalos = 100 # Um número par para boa precisão

# 3. Chame a função e imprima o resultado.
resultado = regra_simpson(minha_funcao, limite_inferior, limite_superior, num_intervalos)
print(f"Exemplo 1: Integral de x^2 de {limite_inferior} a {limite_superior}")
print(f"Resultado aproximado: {resultado}")
print("Resultado exato: 0.0\n")
# Out:
# Exemplo 1: Integral de x^2 de 0 a 1
# Resultado aproximado: -3.33066907387547e-18
# Resultado exato: 0.0

# %% [markdown]
# 1000:

# %%
import numpy as np

def regra_simpson(f, a, b, n):
    pontos = []
    
    h = (b - a) / n
    soma = f(a) + f(b)
    pontos.append((h / 3) * soma)

    for i in range(1, n, 2):
        x = a + i * h
        soma += 4 * f(x)
        pontos.append((h / 3) * soma)

    for i in range(2, n, 2):
        x = a + i * h
        soma += 2 * f(x)
        pontos.append((h / 3) * soma)

    plt.plot(pontos, marker='o', linestyle='-', color='r')
    plt.title('2*pi*cos(2*pi*x)')
    plt.xlabel('Índice')

    integral = (h / 3) * soma
    return integral

# --- Exemplo de Uso ---

def minha_funcao(x):
    return np.sin(2 * np.pi * x)

limite_inferior = 0
limite_superior = 1
num_intervalos = 1000 # Um número par para boa precisão

resultado = regra_simpson(minha_funcao, limite_inferior, limite_superior, num_intervalos)
print(f"Exemplo 1: Integral de x^2 de {limite_inferior} a {limite_superior}")
print(f"Resultado aproximado: {resultado}")
print("Resultado exato: 0.0\n")
# Out:
# Exemplo 1: Integral de x^2 de 0 a 1
# Resultado aproximado: -3.073583054735707e-17
# Resultado exato: 0.0

# %% [markdown]
# ![alt text]({8045237D-D137-418E-8082-F1F3DA9E8FA9}.png)

# %% [markdown]
# # # 2

# %% [markdown]
# ![alt text](image-11.png)

# %% [markdown]
# ![alt text](image-12.png)

# %%
######################################################################
#
# Functions to calculate integration points and weights for Gaussian
# quadrature
#
# x,w = gaussxw(N) returns integration points x and integration
#           weights w such that sum_i w[i]*f(x[i]) is the Nth-order
#           Gaussian approximation to the integral int_{-1}^1 f(x) dx
# x,w = gaussxwab(N,a,b) returns integration points and weights
#           mapped to the interval [a,b], so that sum_i w[i]*f(x[i])
#           is the Nth-order Gaussian approximation to the integral
#           int_a^b f(x) dx
#
# This code finds the zeros of the nth Legendre polynomial using
# Newton's method, starting from the approximation given in Abramowitz
# and Stegun 22.16.6.  The Legendre polynomial itself is evaluated
# using the recurrence relation given in Abramowitz and Stegun
# 22.7.10.  The function has been checked against other sources for
# values of N up to 1000.  It is compatible with version 2 and version
# 3 of Python.
#
# Written by Mark Newman <mejn@umich.edu>, June 4, 2011
# You may use, share, or modify this file freely
#
######################################################################

from numpy import ones,copy,cos,tan,pi,linspace

def gaussxw(N):

    # Initial approximation to roots of the Legendre polynomial
    a = linspace(3,4*N-1,N)/(4*N+2)
    x = cos(pi*a+1/(8*N*N*tan(a)))

    # Find roots using Newton's method
    epsilon = 1e-15
    delta = 1.0
    while delta>epsilon:
        p0 = ones(N,float)
        p1 = copy(x)
        for k in range(1,N):
            p0,p1 = p1,((2*k+1)*x*p1-k*p0)/(k+1)
        dp = (N+1)*(p0-x*p1)/(1-x*x)
        dx = p1/dp
        x -= dx
        delta = max(abs(dx))

    # Calculate the weights
    w = 2*(N+1)*(N+1)/(N*N*(1-x*x)*dp*dp)

    return x,w

def gaussxwab(N,a,b):
    x,w = gaussxw(N)
    return 0.5*(b-a)*x+0.5*(b+a),0.5*(b-a)*w

# %% [markdown]
# ![alt text](image-2.png)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![alt text](image-3.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return (x**2) / (np.exp(x) - 1)

pontos = []
x = 0
while x <= 10:
    pontos.append(f(x))
    x += 0.1

plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()


#quadratura
N = 3
a = 0.001
b = 2.0
# Calculate the sample points and weights, then map them
# to the required integration domain
x,w = gaussxw(N)
xp = 0.5*(b-a)*x + 0.5*(b+a)
wp = 0.5*(b-a)*w
# Perform the integration

pontos = []
s = 0.0
for k in range(N):
    s += wp[k]*f(xp[k]) 
    pontos.append(s)
print(f'Quadratura: {s}')


# Numerical integration using the trapezoidal rule
N = 10
a = 0.01
b = 2.0
h = (b-a)/N
s = 0.5*f(a) + 0.5*f(b)

pontos = []
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(f'trapezio: {h*s}')


plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_20251/1805779528.py:5: RuntimeWarning: invalid value encountered in scalar divide
#   return (x**2) / (np.exp(x) - 1)
# Quadratura: 0.9861573517428778
# trapezio: 0.9825254433710696

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![alt text](image-4.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3 * np.exp(-x**2)

pontos = []
x = 0
while x <= 4:
    pontos.append(f(x))
    x += 0.01

plt.plot(pontos)
plt.title("Plot of f(x) = x**3 * np.exp(-x**2)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()


#quadratura
N = 3
a = 0.0
b = 2.0
# Calculate the sample points and weights, then map them
# to the required integration domain
x,w = gaussxw(N)
xp = 0.5*(b-a)*x + 0.5*(b+a)
wp = 0.5*(b-a)*w
# Perform the integration

pontos = []
s = 0.0
for k in range(N):
    s += wp[k]*f(xp[k]) 
    pontos.append(s)
print(f'Quadratura: {s}')


# Numerical integration using the trapezoidal rule
N = 10
a = 0.1
b = 2.0
h = (b-a)/N
s = 0.5*f(a) + 0.5*f(b)

pontos = []
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(f'  trapezio: {h*s}')


plt.plot(pontos)
plt.title("Plot of f(x) = x**3 * np.exp(-x**2)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()
# Out:
# Quadratura: 0.4662034550560857
#   trapezio: 0.45300378157148813

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![![alt text](image-6.png)](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return 1 / (x**(1/2) * (1+x))

pontos = []
x = 0.0001
while x <= 1:
    pontos.append(f(x))
    x += 0.001

plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()

#quadratura
N = 3
a = 0.0
b = 2.0
# Calculate the sample points and weights, then map them
# to the required integration domain
x,w = gaussxw(N)
xp = 0.5*(b-a)*x + 0.5*(b+a)
wp = 0.5*(b-a)*w
# Perform the integration

pontos = []
s = 0.0
for k in range(N):
    s += wp[k]*f(xp[k]) 
    pontos.append(s)
print(f'Quadratura: {s}')

# Numerical integration using the trapezoidal rule
N = 10
a = 0.1
b = 2.0
h = (b-a)/N
s = 0.5*f(a) + 0.5*f(b)

pontos = []
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(f'  trapezio: {h*s}')


plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()
# Out:
# Quadratura: 1.549673782923239
#   trapezio: 1.3426884771011312

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![alt text](image-8.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.cos(x) / (1 + x**2)

pontos = []
x = 0.0001
while x <= 20:
    pontos.append(f(x))
    x += 0.001

plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()

#quadratura
N = 3
a = 0.0
b = 2.0
# Calculate the sample points and weights, then map them
# to the required integration domain
x,w = gaussxw(N)
xp = 0.5*(b-a)*x + 0.5*(b+a)
wp = 0.5*(b-a)*w
# Perform the integration

pontos = []
s = 0.0
for k in range(N):
    s += wp[k]*f(xp[k]) 
    pontos.append(s)
print(f'Quadratura: {s}')


# Numerical integration using the trapezoidal rule
N = 10
a = 0.0
b = 2.0
h = (b-a)/N
s = 0.5*f(a) + 0.5*f(b)

pontos = []
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(f'  trapezio: {h*s}')


plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()
# Out:
# Quadratura: 0.7283555809938291
#   trapezio: 0.7281505919544462

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![alt text](image-10.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.sin(x) * np.exp(-0.1*x) * (x**-1)

pontos = []
x = 0.0001
while x <= 40:
    pontos.append(f(x))
    x += 0.001

plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()



#quadratura
N = 3
a = 0.0
b = 2.0
# Calculate the sample points and weights, then map them
# to the required integration domain
x,w = gaussxw(N)
xp = 0.5*(b-a)*x + 0.5*(b+a)
wp = 0.5*(b-a)*w
# Perform the integration

pontos = []
s = 0.0
for k in range(N):
    s += wp[k]*f(xp[k]) 
    pontos.append(s)
print(f'Quadratura: {s}')


# Numerical integration using the trapezoidal rule
N = 10
a = 0.1
b = 2.0
h = (b-a)/N
s = 0.5*f(a) + 0.5*f(b)

pontos = []
for k in range(1,N):
    s += f(a+k*h)
    pontos.append(s)
print(f'  trapezio: {h*s}')


plt.plot(pontos)
plt.title("Plot of f(x) = x^2 / (e^x - 1)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()
# Out:
# Quadratura: 1.4721100050845646
#   trapezio: 1.371875453854845

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3

# %%
import numpy as np
from numpy import *


# Definindo a funcao f(x)-------------------------------------------------
def f(x):
    return x * np.exp(-x)

# Definindo funcao  para executar o metodo do trapezoide------------------
def trapezoide(a,b,n):
	h=(b-a)/n
	s=0
	for i in range(n-1):
		s+=f(a+h*(i+1))
	return h/2*(f(a)+2*s+f(b))

# Definindo funcao  para executar o metodo de Romberg---------------------
def romberg(k,j,a,b):
	if k == 1:
		return trapezoide(a,b,2**(j-1))
	else:
		return (4**(k-1)*romberg(k-1,j+1,a,b)-romberg(k-1,j,a,b))/(4**(k-1)-1)


# Execucao e comparacao dos resultados------------------------------------
ordem = 6
rom = zeros((ordem,ordem))

# Metodo do trapezio------------------------------------------------------
for i in range(0,ordem):
	rom[i,0] = trapezoide(0,11,2**i)

print("Trapezio:\n", rom, "\n\n")

# Metodo de Romberg de maneira analitica----------------------------------
for i in arange(1,ordem):
	for j in arange(i,ordem):
		rom[j,i] = rom[j,i-1]+(rom[j,i-1]-rom[j-1,i-1])/(4**i-1)

print("Romberg:\n",rom, "\n\n")

pontos = []
for i in range(0,6):
	pontos.append(rom[i,0])

plt.plot(pontos)
plt.title("Plot of f(x) = x * np.exp(-x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid()
plt.show()
# Out:
# Trapezio:
#  [[0.00101045 0.         0.         0.         0.         0.        ]
#  [0.12413006 0.         0.         0.         0.         0.        ]
#  [0.55144679 0.         0.         0.         0.         0.        ]
#  [0.85606768 0.         0.         0.         0.         0.        ]
#  [0.9613187  0.         0.         0.         0.         0.        ]
#  [0.99000884 0.         0.         0.         0.         0.        ]]
#
#
# Romberg:
#  [[0.00101045 0.         0.         0.         0.         0.        ]
#  [0.12413006 0.16516993 0.         0.         0.         0.        ]
#  [0.55144679 0.69388569 0.72913341 0.         0.         0.        ]
#  [0.85606768 0.95760798 0.97518947 0.97909512 0.         0.        ]
#  [0.9613187  0.99640237 0.99898866 0.99936642 0.99944592 0.        ]
#  [0.99000884 0.99957222 0.99978354 0.99979616 0.99979785 0.99979819]]
